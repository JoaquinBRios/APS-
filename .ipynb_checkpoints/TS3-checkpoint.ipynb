# %% [markdown]
# ## <img src="logo_UNSAM.jpg" align="right" width="300" height="300"> *Análisis y precesamiento de señales*
# <h3 style="font-weight: normal;">Alumno: Joaquín Rios</h3>
# &nbsp;
# &nbsp;
#
# ## |  Trabajo Semanal N°3

# %% [markdown]
# &emsp;&emsp;&emsp; Para el siguente trabajo semanal se observará un fenómeno que en los trabajos pasados no se dió debido a las condiciones en las que
# se daban las señales a analizar en dichos casos. Hablamos de lo que se conoce como **Leakage** o **Derramamiento espectral**, el cual se produce cuando se intenta muestrear una señal con una frecuencia $f_0$ , cuyo valor se encuentra entre un *bin* y su consecutivo, es decir que está por fuera de los múltiplos de la resolución espectral ($Δf$)
#
# &nbsp;
# &emsp;&emsp;&emsp; Vamos a determinar los parámetros a utilizar. El más importante será el factor $k_0$, el cual me define la cantidad de períodos que entran en la N cantidad de muestras, o básicamente el Bin en el que estoy. Además tomaremos el parámetro $Ps$ como facotr determinante para la potencia de la señal, la cual tiene varianza unitaria. Lo demás parámetros se mantendrán iguales a las TS anteriores, e iremos variando este nuevo factor $k_0$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

N=1000
Ps = 1
fs = 1000
nn = np.arange(N)
k= N/4
ff= k* (fs/N)
vmax =np.sqrt(2*Ps)

# %% [markdown]
# ### | Construcción de las señales y cálculo de potencias
# &emsp;&emsp;&emsp; Vamos a ir variando el factor de $k$ de esta señal y ver qué ocurre para cada caso, además, en particular vamos a calcular la potencia de cada *PSD* verificando que cumpla la energía unitaria que planteamos al principio.

# %% [markdown]
# #### | Señal con $k = \frac{N}{4}$

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Parte Temporal
tt = np.arange(0, N) / fs
xx = vmax * np.sin(2*np.pi*ff*tt)

#Hago una t fina para que se vea mejor el gráfico temporal
tt_fina = np.linspace(0, tt[-1], 10000)
xx_fina = vmax * np.sin(2*np.pi*ff*tt_fina)

ax1.plot(tt_fina, xx_fina, label=f"Señal sinusoidal de {ff} Hz",color='green')
ax1.set_title("Representación en el dominio del tiempo")
ax1.set_xlabel("tiempo [segundos]")
ax1.set_ylabel("Magnitud de Señal [Volts]")
ax1.grid(True)
ax1.set_xlim(0, 5*(N/fs)/(k*fs/N))  # muestra 5 períodos
ax1.legend(loc="upper right", fontsize=6) 

# Parte Frecuencial
fftxxC = fft(xx)
fftxx = fft(xx)[:N//2]
fftxx_abs = np.abs(fftxx) / N
freq = fftfreq(N, 1/fs)[:N//2]

ax2.plot(freq, 20*np.log10(fftxx_abs),color='red')
ax2.set_title("Representación en el dominio de la frecuencia")
ax2.set_xlabel("Frecuencia [Hertz]")
ax2.set_ylabel("|V[w]| [dB]")
ax2.grid(True)

plt.show()

PotTiempo = np.sum(np.abs(xx)**2) / N
PotFrecuencia = np.sum(np.abs(fftxxC)**2) / N**2 #Es N cuadrado ya que para frecuencia se ttoma 1/N y luego hay que normalizar por 1/N nuevamente 

print("Potencia con la formula temporal: ",PotTiempo,"Watt")
print("Potencia con la formula frecuencial: ",PotFrecuencia,"Watt")
# Out:
# Potencia con la formula temporal:  1.0000000000000002 Watt
# Potencia con la formula frecuencial:  1.0000000000000002 Watt

# %% [markdown]
# &emsp;&emsp;&emsp; Este primer ejemplo es típico, donde tenemos una frecuencia que es múltiplo de la resolución espectral. Observamos en el apartado de frecuencial que tenemos una única componente que acumula toda la energía teóricamente, aunque como bien sebemos debido al error computacional existente, hay energía con niveles de magnitud muy bajos, que representan prácticamente nada de la energía total. Vemos también el cálculo de la potencia que, como era de esperarse, nos termina dando un valor de $1 Watt$. En este caso donde k es entero y la energía cae en un único bin (sin tomar en cuenta el ruido) lo conocemos como **muestreo coherente** y refiere a una línea espectal válida en mi resolución espectral.

# %% [markdown]
# #### | Señal con $k = \frac{N}{4} + 0.25$

# %%
# Parte Temporal
k= (N/4) + 0.25
ff= k* (fs/N)

tt = np.arange(0, N) / fs
xx = vmax * np.sin(2*np.pi*ff*tt)

# Parte Frecuencial
fftxxC = fft(xx)
fftxx = fft(xx)[:N//2]
fftxx_abs = np.abs(fftxx) / N
freq = fftfreq(N, 1/fs)[:N//2]

plt.figure(figsize=(12, 8))
plt.plot(freq, 20*np.log10(fftxx_abs), label=f"Señal sinusoidal de {ff} Hz",color='green', marker="o")
plt.title("Representación en el dominio de la frecuencia")
plt.xlabel("Frecuencia [Hertz]")
plt.ylabel("|V[w]| [dB]")
plt.xticks(np.arange(0, max(freq)+50, 50))  
plt.grid(True)
plt.legend(loc="upper right", fontsize=8) 

plt.show()

PotTiempo = np.sum(np.abs(xx)**2) / N
PotFrecuencia = np.sum(np.abs(fftxxC)**2) / N**2 #Es N cuadrado ya que para frecuencia se ttoma 1/N y luego hay que normalizar por 1/N nuevamente 

print("Potencia con la formula temporal: ",PotTiempo,"Watt")
print("Potencia con la formula frecuencial: ",PotFrecuencia,"Watt")
# Out:
# Potencia con la formula temporal:  0.9989999999999998 Watt
# Potencia con la formula frecuencial:  0.9989999999999996 Watt

# %% [markdown]
# &emsp; Acá vemos claramente el concepto de **Leakage**, donde la frecuencia de la señal no cae exactamente una una línea espectral de la resolución, provocando que la energía no esté concentrada en un único bin, sino que se distribuya por todo el espectro en diferentes bins. Este "derramamiento" se produce debido a la ventana que estamos tomando, al reconstruir la señal se genera una especie de impulso al final del período, el cual genera un **efecto de borde** en la transformada, provocando que la función sea periódica pero no contínua al termino de cada período. La no continuidad de la señal en esos puntos, debido a las características implícitas de la *DFT*, adhiere componentes frecuenciales que se suman al espectro, distribuyendo su peso (es decir su energía) entre todas estas. Con respecto a la energía, cabe destacar que tendremos siempre la misma potencia unitaria, pero distribuida en los distintos bins. Destacamos que, frente a un corrimiento tan pequeño en frecuencia, la potencia se concentra especialmente en el rango entre $230-270 Hz$, y las frecuencias muy bajas apenas contribuyen.
#
#
# <img src="EjemploLeakage.jpg"  align = "center" width="800" height="800">
#
# &nbsp; En el gráfico que vemos arriba de observa el *efecto de borde* mencionado en el párrafo anterior. Matemáticamente se puede deducir que ante un impulso en el dominio del tiempo, se presenta un espectro contínuo en el dominio de la frecuencia, ya que la transformada de fourier es incapaz de representar ese salto abrupto con la frecuencia de la señal, este fenómeno es el que se ve en este caso.
#
# &nbsp; A pesar de lo mencionados antes, el efecto de leakeage no se debe únicamente a esto, es más, ese tipo de Leakeage se lo conoce como **spectral leakeage**, pero este fenómeno se produce siempre que estemos viendo una frecuencia distinta a la que corresponde en la resolución espectral, en este caso se asocia con el ventaneo fuera de resolución, pero en definitiva, no son lo mismo pero están muy asociados.

# %% [markdown]
# #### | Señal con $k = \frac{N}{4} + 0.5$

# %%
# Parte Temporal
k= (N/4) + 0.5
ff= k* (fs/N)

tt = np.arange(0, N) / fs
xx = vmax * np.sin(2*np.pi*ff*tt)

#Hago una t fina para que se vea mejor el gráfico temporal
tt_fina = np.linspace(0, tt[-1], 10000)
xx_fina = vmax * np.sin(2*np.pi*ff*tt_fina)



# Parte Frecuencial
fftxxC = fft(xx)
fftxx = fft(xx)[:N//2]
fftxx_abs = np.abs(fftxx) / N
freq = fftfreq(N, 1/fs)[:N//2]

plt.figure(figsize=(12, 8))
plt.plot(freq, 20*np.log10(fftxx_abs), label=f"Señal sinusoidal de {ff} Hz",color='green', marker="o")
plt.title("Representación en el dominio de la frecuencia")
plt.xlabel("Frecuencia [Hertz]")
plt.ylabel("|V[w]| [dB]")
plt.grid(True)
plt.xlim(150,350)
plt.legend(loc="upper right", fontsize=8) 

plt.show()

PotTiempo = np.sum(np.abs(xx)**2) / N
PotFrecuencia = np.sum(np.abs(fftxxC)**2) / N**2 #Es N cuadrado ya que para frecuencia se ttoma 1/N y luego hay que normalizar por 1/N nuevamente 

print("Potencia con la formula temporal: ",PotTiempo,"Watt")
print("Potencia con la formula frecuencial: ",PotFrecuencia,"Watt")
# Out:
# Potencia con la formula temporal:  1.0000000000000004 Watt
# Potencia con la formula frecuencial:  1.0000000000000004 Watt

# %% [markdown]
# &emsp; Aquí se ve lo que ocurre cuando la frecuencia de la señal original se encuentra en medio del intervalo para pasar de un múltiplo de la resolución espectral a otro. Se hizo un zoom local para observar lo que sucede con los bins, ya que en un principio, en una primer mirada del gráfico, parecía que la magnitud se encontraba concentrada en un solo bin, pero al acercarlo vemos como la energía se reparte en partes prácticamente iguales entre los bins designados a las frecuencias **250** y **251 Hz**, lo cual es coherente con lo que planteamos, donde la frecuencia se encuentra en el centro del paso entre estos dos valores, con lo cual la FFT no elige y reparte en partes iguales la potencia entre estos dos bins, luego vemos que para frecuencias bajas este sigue teniendo una potencia considerable.
#
# &emsp; En el ejemplo anterior vimos que, al estar más cerca de la frecuencia inferor, la energía se concentraba más en el bin correspondiente a **250 Hz**, y luego había una compesación en el siguente, pero se veía un acumulamiento en el bin más cercano.

# %% [markdown]
# #### | Señal con $k = \frac{N}{4} + 0.25$ y Zero Padding

# %%
# Parte Temporal
k= (N/4) + 0.25
ff= k* (fs/N)

tt = np.arange(0, N) / fs
xx = vmax * np.sin(2*np.pi*ff*tt)
#Creo vector para Zero Padding
VZ = np.zeros(9*N)
xx = np.concatenate((xx, VZ))

# Parte Frecuencial
fftxxC = fft(xx)
fftxx = fft(xx)[:(len(xx))//2]
fftxx_abs = np.abs(fftxx) / (len(xx))
freq = fftfreq((len(xx)), 1/fs)[:(len(xx))//2]

plt.figure(figsize=(12, 8))
plt.plot(freq, 20*np.log10(fftxx_abs), label=f"Señal sinusoidal de {ff} Hz",color='green', marker="o")
plt.title("Representación en el dominio de la frecuencia")
plt.xlabel("Frecuencia [Hertz]")
plt.ylabel("|V[w]| [dB]")
plt.xticks(np.arange(0, max(freq)+50, 50))  
plt.grid(True)
plt.legend(loc="upper right", fontsize=8) 

plt.show()

PotTiempo = np.sum(np.abs(xx)**2) / N
PotFrecuencia = np.sum(np.abs(fftxxC)**2) / (((N)**2)*10) #Es N cuadrado ya que para frecuencia se ttoma 1/N y luego hay que normalizar por 1/N nuevamente 

print("Potencia con la formula temporal: ",PotTiempo,"Watt")
print("Potencia con la formula frecuencial: ",PotFrecuencia,"Watt")
# Out:
# Potencia con la formula temporal:  0.9989999999999998 Watt
# Potencia con la formula frecuencial:  0.9989999999999997 Watt

# %% [markdown]
# &emsp; Lo primero que notamos al agregar ceros en la función, es que el gráfico de frecuencia cambia contundentemente con respecto al anterior no solo porque vemos la transformada mejor representada, sino porque podemos ubicar fácilmente en el gráfico los picos, y cómo se distribuye la energía. El **Zero Padding** es una técnica que no elimina el leakage, lo estamos viendo en la figura, pero si representa mejor la señal en el dominio de la frecuencia agregando ceros al final de la señal. Es importante entender además por qué se están agregando ceros en el final y no tal vez entre dato y dato, o al principio, lo cual podría ser un pensamiento válido en un principio, pero debe ser claro el hecho de que, en medio de la señal, no podemos poner ceros ya que estaríamos modificando la señal original, su valor medio y cómo se comporta.
#
# &emsp; Por otro lado, no se introducen ceros al principio ya que, aunque en este momento solo estemos viendo el módulo de la señal analizada, al estar atrasada en el tiempo, la señal la vevmos con una fase distinta a la origial.
#
# &emsp; Otro detalle más interesante podría ser la similitud que se ve con la salida en frecuencia de la ventana rectangular, podemos ver una especie de *sinc* que se está formando, tomando como valor central la frecuencia que estamos observando.

# %% [markdown]
# #### | Señal con $k = \frac{N}{4} + 0.25$ y Zero Padding

# %%
# Parte Temporal
k= (N/4) + 0.5
ff= k* (fs/N)

tt = np.arange(0, N) / fs
xx = vmax * np.sin(2*np.pi*ff*tt)
#Creo vector para Zero Padding
VZ = np.zeros(9*N)
xx = np.concatenate((xx, VZ))

# Parte Frecuencial
fftxxC = fft(xx)
fftxx = fft(xx)[:(len(xx))//2]
fftxx_abs = np.abs(fftxx) / (len(xx))
freq = fftfreq((len(xx)), 1/fs)[:(len(xx))//2]

plt.figure(figsize=(12, 8))
plt.plot(freq, 20*np.log10(fftxx_abs), label=f"Señal sinusoidal de {ff} Hz",color='green', marker="o")
plt.title("Representación en el dominio de la frecuencia")
plt.xlabel("Frecuencia [Hertz]")
plt.ylabel("|V[w]| [dB]")
plt.xticks(np.arange(0, max(freq), 50))  
plt.grid(True)
plt.legend(loc="upper right", fontsize=8) 
plt.xlim(243, 258)
plt.ylim(-100, -20)

plt.show()

PotTiempo = np.sum(np.abs(xx)**2) / N
PotFrecuencia = np.sum(np.abs(fftxxC)**2) / ((len(xx)**2))

print("Potencia con la formula temporal: ",PotTiempo,"Watt")
print("Potencia con la formula frecuencial: ",PotFrecuencia,"Watt")
# Out:
# Potencia con la formula temporal:  1.0000000000000004 Watt
# Potencia con la formula frecuencial:  0.10000000000000002 Watt

# %% [markdown]
# &emsp; Para la muestra de este gráfico se decidió mostrar un intervalo particular para poder ver de mejor manera la respuesta al impulso de la ventana rectangular o **sinc** nombrada anteriormente. Esta respuesta al impulso de la ventana justamente es lo que nos genera el leakage una vez que nos pasamos de la resolución espectral, ya que la cantidad finita de muestras es multiplicada por esta ventana, pero al estar sumando muestras artificiales que son ceros, podemos observar este espectro característico. Es evidente que aquí vemos el comportamiento de la ventana en su dominio de frecuencia, pero también es interesante resaltar que observamos más puntos entre una frecuencia y otra, pudiendo tener una caracterización de la señal más adecuada.

# %% [markdown]
# ### | Conclusiones
# &emsp; En el desarrollo de esta tarea se pudieron ver detenidamente tanto el fenómeno de **Leakage** como el del **Zero Padding**. Se observó que la ponderación de la potencia en el Leakage depende de la ubicación en la que se encuentre entre estos dos múltiplos de la resolución, viendo que para *0.5 Hz* las amplitudes ponderaban a la mitad entre los dos bins y para el de *0.25 Hz* se ponderaba más el bin cercano a este valor. Por otro lado el cálculo de potencias nos dió igual en todas, únicamente con pequeñas variaciones por métodos numéricos, lo que es compárable con nuestra suposición teórica, que que aunque se presente el fenómeno antes mencionado, este efecto justamente desparrama la energía ya existente y la "guarda" en los distintos bins de los alrededores.
#
# &emsp; Por úlitmo cabe destacar que al hacer *Zero Padding* vimos que el espectro de la señal se visualizaba mejor, ya que mejoró la resolución de esta, pero no desaparece el leakage por este método, e incluso se pudo ver la forma de la respuesta al impulso de la ventana elegida.
